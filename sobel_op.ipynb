# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadTausif/python-code-examples/blob/main/sobel_op.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

# Apply Sobel operator
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=31)  # Horizontal edges
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=31)  # Vertical edges

# Calculate gradient magnitude
sobel_magnitude = np.sqrt(sobel_x**2 + sobel_y**2)
sobel_magnitude = np.uint8(sobel_magnitude / np.max(sobel_magnitude) * 255)

# Display results
plt.figure(figsize=(10, 8))
plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')

plt.subplot(1, 3, 2)
plt.title("Sobel Magnitude")
plt.imshow(sobel_magnitude, cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Sobel X + Y Combined")
plt.imshow(cv2.addWeighted(np.abs(sobel_x), 0.5, np.abs(sobel_y), 0.5, 0), cmap='gray')

plt.show()

# %%
# prompt: create histogram of image

import cv2
import matplotlib.pyplot as plt

# Load the image (make sure 'image.jpg' is in the current directory or provide the correct path)
image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

if image is None:
    print("Error: Could not load image. Please check the file path.")
else:
    # Calculate the histogram
    hist = cv2.calcHist([image], [0], None, [256], [0, 256])

    # Plot the histogram
    plt.figure()
    plt.title("Grayscale Histogram")
    plt.xlabel("Bins")
    plt.ylabel("Number of Pixels")
    plt.plot(hist)
    plt.xlim([0, 256])
    plt.show()

# %%
# prompt: create histogram of image

import cv2
import matplotlib.pyplot as plt

# Load the image (make sure 'image.jpg' is in the current directory or provide the correct path)
image = cv2.imread('people.jpg', cv2.IMREAD_GRAYSCALE)

if image is None:
    print("Error: Could not load image. Please check the file path.")
else:
    # Calculate the histogram
    hist = cv2.calcHist([image], [0], None, [256], [0, 256])

    # Plot the histogram
    plt.figure()
    plt.title("Grayscale Histogram")
    plt.xlabel("Bins")
    plt.ylabel("Number of Pixels")
    plt.plot(hist)
    plt.xlim([0, 256])
    plt.show()

# %%
# prompt: create histogram of image

import cv2
import matplotlib.pyplot as plt
import seaborn as sns

# Load the image (make sure 'image.jpg' is in the current directory or provide the correct path)
image = cv2.imread('fruits.jpg', cv2.IMREAD_GRAYSCALE)

if image is None:
    print("Error: Could not load image. Please check the file path.")
else:
    # Calculate the histogram
    hist = cv2.calcHist([image], [0], None, [256], [0, 256])

    # Plot the histogram
    plt.figure()
    plt.title("Grayscale Histogram")
    plt.xlabel("Bins")
    plt.ylabel("Number of Pixels")
    plt.plot(hist)
    plt.xlim([0, 256])
    plt.show()

# %%
# prompt: use seaborn to display, and style like ggplot2 in R

import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
data = {'Category': ['A', 'B', 'C', 'A', 'B', 'C'],
        'Value': [10, 15, 12, 8, 18, 14]}

# Create a Seaborn bar plot with ggplot2-like styling
sns.set_style("whitegrid")  # Set the background style
plt.figure(figsize=(8, 6)) # Adjust figure size

# Create the bar plot
sns.barplot(x='Category', y='Value', data=data, palette='Set2') # Set color palette


# Customize plot elements for a ggplot2 look
plt.title('Bar Plot Example', fontsize=16, fontweight='bold')
plt.xlabel('Categories', fontsize=12)
plt.ylabel('Values', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine()  # Remove top and right spines


# Display the plot
plt.show()
# Out:
# <ipython-input-15-3d3e76a586d8>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Value', data=data, palette='Set2') # Set color palette

# %%
# prompt: frequency distribution

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image (ensure 'image.jpg' is in the same directory or provide the full path)
image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

# Calculate the histogram
hist, bins = np.histogram(image.flatten(), 256, [0, 256])

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.title("Grayscale Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.xlim([0, 256])  # Set x-axis limits
plt.plot(hist)
plt.show()

# %%
# prompt: fourir

import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
img = cv2.imread('image.jpg',0)

# Perform Fourier Transform
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

# Display the results
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # New Section

# %%
# prompt: smooth image with gaussian filter

import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
img = cv2.imread('fruits.jpg')

# Apply Gaussian blur
blur = cv2.GaussianBlur(img,(11,11),0)

# Display the original and blurred images
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# prompt: do more blurred

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('fruits.jpg')

# Apply Gaussian blur with a larger kernel size for more blurring
blur = cv2.GaussianBlur(img,(21,21),0) # Increased kernel size to (21, 21)

# Display the original and blurred images
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('More Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# prompt: use convolation to detect freatures

import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image (replace 'your_image.jpg' with your image file)
img = cv2.imread('image.jpg', 0)

# Define the convolution kernel (example: a 3x3 averaging filter)
kernel = np.ones((5, 5), np.float32) / 25  # The kernel values are divided by 25 for normalization

# Perform convolution
dst = cv2.filter2D(img, -1, kernel)

# Display the original and convolved images
plt.subplot(121), plt.imshow(img, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(dst, cmap='gray')
plt.title('Convolved Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# !pip install PyMuPDF
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 58.8 MB/s eta 0:00:00
# ...

# %%
# prompt: I have a PDF document, it has about A4 size, and want to cut the each page to hald.

import fitz  # PyMuPDF

def split_pdf_pages(input_pdf, output_prefix):
    """Splits each page of a PDF into two halves (top and bottom)."""
    try:
        pdf_document = fitz.open(input_pdf)
        for page_num in range(pdf_document.page_count):
            page = pdf_document[page_num]
            page_width = page.rect.width
            page_height = page.rect.height

            # Calculate the middle point for splitting
            mid_height = page_height / 2

            # Create two new pages for top and bottom halves
            top_half_page = fitz.open()
            top_half_page.insert_pdf(pdf_document, from_page=page_num, to_page=page_num)
            top_half_page[0].set_mediabox(0, 0, page_width, mid_height)

            bottom_half_page = fitz.open()
            bottom_half_page.insert_pdf(pdf_document, from_page=page_num, to_page=page_num)
            bottom_half_page[0].set_mediabox(0, mid_height, page_width, page_height)


            # Save the half pages
            top_half_page.save(f"{output_prefix}_page_{page_num + 1}_top.pdf")
            bottom_half_page.save(f"{output_prefix}_page_{page_num + 1}_bottom.pdf")

            top_half_page.close()
            bottom_half_page.close()

        pdf_document.close()
        print(f"PDF splitting complete. Output files saved with prefix '{output_prefix}'.")

    except FileNotFoundError:
        print(f"Error: Input PDF file '{input_pdf}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
split_pdf_pages("1. Introduction.pdf", "output") # Replace your_input.pdf with actual filename
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-56bfe93edede> in <cell line: 3>()
#       1 # prompt: I have a PDF document, it has about A4 size, and want to cut the each page to hald.
#       2
# ----> 3 import fitz  # PyMuPDF
#       4
#       5 def split_pdf_pages(input_pdf, output_prefix):
#
# ModuleNotFoundError: No module named 'fitz'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# prompt: list all the PDF files I uploaed

import os

def list_pdf_files(directory="."):
    """Lists all PDF files in the specified directory."""
    pdf_files = []
    for filename in os.listdir(directory):
        if filename.lower().endswith(".pdf"):
            pdf_files.append(filename)
    return pdf_files

# Example usage (lists PDF files in the current directory):
uploaded_pdfs = list_pdf_files()

if uploaded_pdfs:
    print("Uploaded PDF files:")
    for pdf_file in uploaded_pdfs:
        print(pdf_file)
else:
    print("No PDF files found in the current directory.")
# Out:
# Uploaded PDF files:
# 3. Point Processing.pdf
# 6. Image Segmentation I.pdf
# 5. Morphological Image Processing.pdf
# 4. SpatialFiltring.pdf
# 2. Histogram Processing.pdf
# 6. image segmentation complete.pdf
# 1. Introduction.pdf
